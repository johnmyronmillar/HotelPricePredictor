# %% [markdown]
# # Data Preparation for Machine Learning
#
# The purpose of this workbook is to take the cleaned dataframe and prepare the data for machine learning applications.

# %%
# Import libraries

import numpy as np
import pandas as pd
import hvplot.pandas
from collections import Counter
from pathlib import Path
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 

import warnings
warnings.filterwarnings('ignore')

# %%
# Set the random seed for reproducibility
from numpy.random import seed
seed(1)
from tensorflow import random
random.set_seed(2)

# %%
# Load the cleaned hotel booking data into the workbook and convert to pandas Dataframe
csv_path = Path('../Resources/cleaned_hotel_bookings.csv')

df = pd.read_csv(csv_path)
df.head()
# Out:
#    Unnamed: 0         hotel  lead_time  arrival_date_year  arrival_date_month  \
# 0           2  Resort Hotel          7               2015                   7
# 1           4  Resort Hotel         14               2015                   7
# 2           5  Resort Hotel         14               2015                   7
# 3           6  Resort Hotel          0               2015                   7
# 4           7  Resort Hotel          9               2015                   7
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults meal country  \
# 0                        0                     1       1   BB     GBR
# 1                        0                     2       2   BB     GBR
# 2                        0                     2       2   BB     GBR
# 3                        0                     2       2   BB     PRT
# 4                        0                     2       2   FB     PRT
#
#   market_segment reserved_room_type customer_type    adr  \
# 0         Direct                  A     Transient   75.0
# 1      Online TA                  A     Transient   98.0
# 2      Online TA                  A     Transient   98.0
# 3         Direct                  C     Transient  107.0
# 4         Direct                  C     Transient  103.0
#
#    total_of_special_requests        date
# 0                          0  2015-07-01
# 1                          1  2015-07-01
# 2                          1  2015-07-01
# 3                          0  2015-07-01
# 4                          1  2015-07-01

# %%
# Drop unamed row
df = df.drop(columns = ['Unnamed: 0'])

# %%
# Confirm there are no null values in the dataset
df.isnull().values.any()
# Out:
# False

# %%
df.dtypes
# Out:
# hotel                         object
# lead_time                      int64
# arrival_date_year              int64
# arrival_date_month             int64
# arrival_date_week_number       int64
# arrival_date_day_of_month      int64
# stays_in_weekend_nights        int64
# stays_in_week_nights           int64
# adults                         int64
# meal                          object
# country                       object
# market_segment                object
# reserved_room_type            object
# customer_type                 object
# adr                          float64
# total_of_special_requests      int64
# date                          object
# dtype: object

# %%
# # get dummies
# dummy_columns = ['meal', 'reserved_room_type', 'market_segment', 'deposit_type', 'customer_type']
# df = pd.get_dummies(df, columns = dummy_columns)
# df.head()

# %%
# # Plot the data
# df.hist(figsize = (12,10))

# %%
# Correlation between numerical values
df.corr()
# Out:
#                            lead_time  arrival_date_year  arrival_date_month  \
# lead_time                   1.000000           0.041679            0.130384
# arrival_date_year           0.041679           1.000000           -0.510824
# arrival_date_month          0.130384          -0.510824            1.000000
# arrival_date_week_number    0.125707          -0.524981            0.994504
# arrival_date_day_of_month   0.000493          -0.002051           -0.028305
# stays_in_weekend_nights     0.051026           0.018572            0.015045
# stays_in_week_nights        0.137724           0.033185            0.016438
# adults                      0.059307           0.044925            0.014899
# adr                        -0.181161           0.213256            0.087920
# total_of_special_requests  -0.121700           0.106124            0.027529
#
#                            arrival_date_week_number  \
# lead_time                                  0.125707
# arrival_date_year                         -0.524981
# arrival_date_month                         0.994504
# arrival_date_week_number                   1.000000
# arrival_date_day_of_month                  0.070055
# stays_in_weekend_nights                    0.015529
# stays_in_week_nights                       0.013436
# adults                                     0.012347
# adr                                        0.083494
# total_of_special_requests                  0.025492
#
#                            arrival_date_day_of_month  stays_in_weekend_nights  \
# lead_time                                   0.000493                 0.051026
# arrival_date_year                          -0.002051                 0.018572
# arrival_date_month                         -0.028305                 0.015045
# arrival_date_week_number                    0.070055                 0.015529
# arrival_date_day_of_month                   1.000000                -0.010536
# stays_in_weekend_nights                    -0.010536                 1.000000
# stays_in_week_nights                       -0.022950                 0.443477
# adults                                     -0.001362                 0.082976
# adr                                         0.027724                 0.031640
# total_of_special_requests                   0.000918                 0.071508
#
#                            stays_in_week_nights    adults       adr  \
# lead_time                              0.137724  0.059307 -0.181161
# arrival_date_year                      0.033185  0.044925  0.213256
# arrival_date_month                     0.016438  0.014899  0.087920
# arrival_date_week_number               0.013436  0.012347  0.083494
# arrival_date_day_of_month             -0.022950 -0.001362  0.027724
# stays_in_weekend_nights                0.443477  0.082976  0.031640
# stays_in_week_nights                   1.000000  0.090195  0.052733
# adults                                 0.090195  1.000000  0.232200
# adr                                    0.052733  0.232200  1.000000
# total_of_special_requests              0.070758  0.133184  0.185971
#
#                            total_of_special_requests
# lead_time                                  -0.121700
# arrival_date_year                           0.106124
# arrival_date_month                          0.027529
# arrival_date_week_number                    0.025492
# arrival_date_day_of_month                   0.000918
# stays_in_weekend_nights                     0.071508
# stays_in_week_nights                        0.070758
# adults                                      0.133184
# adr                                         0.185971
# total_of_special_requests                   1.000000

# %%
# Split data into two dataframes based on 'City Hotel' and 'Resort Hotels'

def hotel_df(df, hotel):
    rslt_df = df.loc[df['hotel'].isin(hotel)]
    return rslt_df

City_hotel = hotel_df(df, ['City Hotel'])

Resort_hotel = hotel_df(df, ['Resort Hotel'])

# %%
City_hotel.head()
# Out:
#             hotel  lead_time  arrival_date_year  arrival_date_month  \
# 28119  City Hotel         88               2015                   7
# 28120  City Hotel         65               2015                   7
# 28121  City Hotel         92               2015                   7
# 28122  City Hotel        100               2015                   7
# 28123  City Hotel         79               2015                   7
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# 28119                        27                          1
# 28120                        27                          1
# 28121                        27                          1
# 28122                        27                          2
# 28123                        27                          2
#
#        stays_in_weekend_nights  stays_in_week_nights  adults meal country  \
# 28119                        0                     4       2   BB     PRT
# 28120                        0                     4       1   BB     PRT
# 28121                        2                     4       2   BB     PRT
# 28122                        0                     2       2   BB     PRT
# 28123                        0                     3       2   BB     PRT
#
#       market_segment reserved_room_type customer_type   adr  \
# 28119      Online TA                  A     Transient  76.5
# 28120      Online TA                  A     Transient  68.0
# 28121      Online TA                  A     Transient  76.5
# 28122      Online TA                  A     Transient  76.5
# 28123      Online TA                  A     Transient  76.5
#
#        total_of_special_requests        date
# 28119                          1  2015-07-01
# 28120                          1  2015-07-01
# 28121                          2  2015-07-01
# 28122                          1  2015-07-02
# 28123                          1  2015-07-02

# %%
Resort_hotel.head()
# Out:
#           hotel  lead_time  arrival_date_year  arrival_date_month  \
# 0  Resort Hotel          7               2015                   7
# 1  Resort Hotel         14               2015                   7
# 2  Resort Hotel         14               2015                   7
# 3  Resort Hotel          0               2015                   7
# 4  Resort Hotel          9               2015                   7
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults meal country  \
# 0                        0                     1       1   BB     GBR
# 1                        0                     2       2   BB     GBR
# 2                        0                     2       2   BB     GBR
# 3                        0                     2       2   BB     PRT
# 4                        0                     2       2   FB     PRT
#
#   market_segment reserved_room_type customer_type    adr  \
# 0         Direct                  A     Transient   75.0
# 1      Online TA                  A     Transient   98.0
# 2      Online TA                  A     Transient   98.0
# 3         Direct                  C     Transient  107.0
# 4         Direct                  C     Transient  103.0
#
#    total_of_special_requests        date
# 0                          0  2015-07-01
# 1                          1  2015-07-01
# 2                          1  2015-07-01
# 3                          0  2015-07-01
# 4                          1  2015-07-01

# %%
print(Resort_hotel.shape)
print(City_hotel.shape)
# Out:
# (28119, 17)
# (74242, 17)

# %%
print(Resort_hotel.dtypes)
print(City_hotel.dtypes)
# Out:
# hotel                         object
# lead_time                      int64
# arrival_date_year              int64
# arrival_date_month             int64
# arrival_date_week_number       int64
# arrival_date_day_of_month      int64
# stays_in_weekend_nights        int64
# stays_in_week_nights           int64
# adults                         int64
# meal                          object
# country                       object
# market_segment                object
# reserved_room_type            object
# customer_type                 object
# adr                          float64
# total_of_special_requests      int64
# date                          object
# dtype: object
# hotel                         object
# lead_time                      int64
# arrival_date_year              int64
# arrival_date_month             int64
# arrival_date_week_number       int64
# arrival_date_day_of_month      int64
# stays_in_weekend_nights        int64
# stays_in_week_nights           int64
# adults                         int64
# meal                          object
# country                       object
# market_segment                object
# reserved_room_type            object
# customer_type                 object
# adr                          float64
# total_of_special_requests      int64
# date                          object
# dtype: object

# %%
Resort_hotel.to_csv('../Resources/Resort_Hotel_Prep.csv')
City_hotel.to_csv('../Resources/City_hotel_Prep.csv')
